# %% [markdown]
# # Get Past 1 Month Prediction
#
# **This notebook fetches data of past 1 month, gathers model predictions, and saves to predictions.json as `history`**

# %%
import requests
import pandas as pd
import json
import numpy as np

# %% [markdown]
# # Get Weather Data

# %% [markdown]
# Geo coords for Dhaka, Chittagong, and Patuakhali

# %%
# tuple as (lat, lon)
dhk_coords = (23.7104, 90.40744)
cht_coords = (22.3384, 91.83168)
pat_coords = (22.36833, 90.3458)

# %%
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

start_date = datetime.now(ZoneInfo("Asia/Dhaka")) - timedelta(
    days=31
)  # 1 month ago date
start_date = start_date.strftime("%Y-%m-%d")
end_date = datetime.now(ZoneInfo("Asia/Dhaka")) - timedelta(days=1)  # yesterday date
end_date = end_date.strftime("%Y-%m-%d")

# %%
start_date
# Out:
# '2025-08-15'

# %%
def get_city_weather(coords, start_date, end_date):
    weather_api_url = f"https://historical-forecast-api.open-meteo.com/v1/forecast?latitude={coords[0]}&longitude={coords[1]}&start_date={start_date}&end_date={end_date}&daily=relative_humidity_2m_mean,temperature_2m_max,temperature_2m_min,temperature_2m_mean,rain_sum,sunshine_duration"
    # weather_api_url = f"https://historical-forecast-api.open-meteo.com/v1/forecast?latitude={coords[0]}&longitude={coords[1]}&start_date={start_date}&end_date={end_date}%hourly=temperature_2m"
    response = requests.get(weather_api_url)

    try:
        response.raise_for_status()
        data = response.json()

        return data
    except requests.exceptions.RequestException as e:
        print(e)

# %%
dhaka_data = get_city_weather(dhk_coords, start_date, end_date)
# dhaka_data

# %%
city_weather_df = pd.DataFrame(
    columns=[
        "Date",  # Remove Date before passed to model
        "Rainfall",
        "Sunshine",
        "Humidity",
        "Temp_mean",
        "Temp_max",
        "Temp_min",
        "Year",
        "Month",
        # "loadshed_prev",
        # "generation_prev",
    ]
)
city_weather_df
# Out:
# Empty DataFrame
# Columns: [Date, Rainfall, Sunshine, Humidity, Temp_mean, Temp_max, Temp_min, Year, Month]
# Index: []

# %%
daily_data = dhaka_data["daily"]

city_weather_df["Date"] = daily_data["time"]
city_weather_df["Date"] = pd.to_datetime(city_weather_df["Date"], format="%Y-%m-%d")
city_weather_df["Year"] = city_weather_df["Date"].dt.year
city_weather_df["Month"] = city_weather_df["Date"].dt.month

city_weather_df["Rainfall"] = daily_data["rain_sum"]
city_weather_df["Sunshine"] = daily_data["sunshine_duration"]
city_weather_df["Sunshine"] = city_weather_df["Sunshine"] / (60 * 60)
city_weather_df["Humidity"] = daily_data["relative_humidity_2m_mean"]

city_weather_df["Temp_mean"] = daily_data["temperature_2m_mean"]
city_weather_df["Temp_max"] = daily_data["temperature_2m_max"]
city_weather_df["Temp_min"] = daily_data["temperature_2m_min"]

city_weather_df
# Out:
#          Date  Rainfall   Sunshine  Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-08-15       0.0  12.000000        83       29.3      33.0      26.4
# 1  2025-08-16       0.0   7.457553        83       29.4      32.7      26.1
# 2  2025-08-17       0.0   5.805636        87       28.9      31.4      27.1
# 3  2025-08-18       0.0  11.005475        78       29.6      33.9      26.5
# 4  2025-08-19       0.0   9.260372        84       28.4      31.9      26.1
# 5  2025-08-20       0.0   5.320253        89       27.6      30.1      25.9
# 6  2025-08-21       0.0   1.424925        91       26.9      29.3      25.2
# 7  2025-08-22       0.0   2.783719        89       27.2      29.3      25.4
# 8  2025-08-23       0.0   1.357611        92       26.7      28.4      25.3
# 9  2025-08-24       0.0   3.094358        89       27.5      29.8      25.7
# 10 2025-08-25       0.0   9.554189        79       29.4      33.2      25.9
# 11 2025-08-26       0.0  11.991942        77       30.0      34.1      26.4
# 12 2025-08-27       0.0  10.933561        80       29.3      33.8      26.3
# 13 2025-08-28       0.0   7.762828        85       28.2      31.6      26.2
# 14 2025-08-29       0.0   8.890681        85       28.5      32.5      26.1
# 15 2025-08-30       0.0  10.120406        85       28.9      32.1      26.4
# 16 2025-08-31       0.0   9.986231        85       29.3      32.5      27.0
# 17 2025-09-01       0.0  11.866444        79       30.8      35.6      27.0
# 18 2025-09-02       0.0  10.248494        79       29.3      33.5      26.8
# 19 2025-09-03       0.0  11.672992        79       29.4      33.6      26.3
# 20 2025-09-04       0.0  10.211678        83       29.2      32.9      26.4
# 21 2025-09-05       0.0  10.939567        80       29.8      34.2      26.8
# 22 2025-09-06       0.0  10.826617        78       30.3      34.0      26.9
# 23 2025-09-07       0.0   7.288361        83       29.3      32.1      26.8
# 24 2025-09-08       0.0  11.082719        83       29.7      34.0      27.3
# 25 2025-09-09       0.0  10.918633        81       29.8      33.5      26.6
# 26 2025-09-10       0.0   7.396239        79       29.9      34.1      26.9
# 27 2025-09-11       0.0   7.923742        84       29.4      33.9      26.7
# 28 2025-09-12       0.0   1.702553        88       28.2      30.4      26.3
# 29 2025-09-13       0.0   9.111464        84       28.8      33.0      26.3
# 30 2025-09-14       1.1   0.000000        94       26.4      27.9      25.3
#
#     Year  Month
# 0   2025      8
# 1   2025      8
# 2   2025      8
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      9
# 18  2025      9
# 19  2025      9
# 20  2025      9
# 21  2025      9
# 22  2025      9
# 23  2025      9
# 24  2025      9
# 25  2025      9
# 26  2025      9
# 27  2025      9
# 28  2025      9
# 29  2025      9
# 30  2025      9

# %%
def get_city_weather_df(daily_data):
    city_df = pd.DataFrame(
        columns=[
            "Date",  # Remove Date before passed to model
            "Rainfall",
            "Sunshine",
            "Humidity",
            "Temp_mean",
            "Temp_max",
            "Temp_min",
            "Year",
            "Month",
            # "loadshed_prev",
            # "generation_prev",
        ]
    )

    city_df["Date"] = daily_data["time"]
    city_df["Date"] = pd.to_datetime(city_df["Date"], format="%Y-%m-%d")
    city_df["Year"] = city_df["Date"].dt.year
    city_df["Month"] = city_df["Date"].dt.month

    city_df["Rainfall"] = daily_data["rain_sum"]
    city_df["Sunshine"] = daily_data["sunshine_duration"]
    # Convert seconds to hours
    city_df["Sunshine"] = city_df["Sunshine"] / (60 * 60)
    city_df["Humidity"] = daily_data["relative_humidity_2m_mean"]

    city_df["Temp_mean"] = daily_data["temperature_2m_mean"]
    city_df["Temp_max"] = daily_data["temperature_2m_max"]
    city_df["Temp_min"] = daily_data["temperature_2m_min"]

    return city_df

# %% [markdown]
# ## Get weather data of all locations

# %%
dhk_data = get_city_weather(dhk_coords, start_date, end_date)
dhk_weather_df = get_city_weather_df(dhk_data["daily"])
dhk_weather_df
# Out:
#          Date  Rainfall   Sunshine  Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025
# 14 2025-08-29       0.0   9.417219        87       27.8      28.4      27.2
# 15 2025-08-30       0.0   8.796036        86       28.1      28.7      27.0
# 16 2025-08-31       0.0  10.874611        86       28.5      29.8      27.1
# 17 2025-09-01       0.0   7.485272        85       29.1      31.5      27.6
# 18 2025-09-02       0.0  10.621506        81       29.0      30.2      27.6
# 19 2025-09-03       0.0  10.156272        82       29.1      30.1      28.2
# 20 2025-09-04       0.0  10.847272        84       28.7      29.7      27.5
# 21 2025-09-05       0.0  10.283642        84       28.8      29.7      27.5
# 22 2025-09-06       0.0  10.022939        85       29.0      29.8      27.6
# 23 2025-09-07       0.0   8.013797        84       28.8      30.0      27.5
# 24 2025-09-08       0.0   8.497022        84       28.9      30.0      27.5
# 25 2025-09-09       0.0   7.490933        85       28.7      29.7      27.3
# 26 2025-09-10       0.0   4.555461        86       28.5      29.6      27.4
# 27 2025-09-11       0.4   2.292514        87       28.3      29.5      27.1
# 28 2025-09-12       0.8   1.932011        87       28.2      28.9      27.5
# 29 2025-09-13       0.0   2.487358        86       28.3      29.2      27.3
# 30 2025-09-14       1.8   2.081208        89       27.3      27.9      26.9
#
#     Year  Month
# 0   2025      8
# 1   2025      8
# 2   2025      8
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      9
# 18  2025      9
# 19  2025      9
# 20  2025      9
# 21  2025      9
# 22  2025      9
# 23  2025      9
# 24  2025      9
# 25  2025      9
# 26  2025      9
# 27  2025      9
# 28  2025      9
# 29  2025      9
# 30  2025      9

# %%
pat_data = get_city_weather(pat_coords, start_date, end_date)
pat_weather_df = get_city_weather_df(pat_data["daily"])
pat_weather_df
# Out:
#          Date  Rainfall   Sunshine  Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-08-15       0.0  11.767625        85       28.8      31.6      26.7
# 1  2025-08-16       0.0   9.782436        84       29.4      32.7      26.8
# 2  2025-08-17       0.0   6.405739        85       28.8      31.8      27.0
# 3  2025-08-18       0.0   9.527064        84       28.4      30.7      26.4
# 4  2025-08-19       0.0   5.333558        87       28.0      31.2      26.4
# 5  2025-08-20       0.0   4.935244        90       27.6      29.6      26.3
# 6  2025-08-21       0.3   0.000000        93       26.8      28.1      25.7
# 7  2025-08-22       0.0   1.770156        92       27.3      29.2      26.1
# 8  2025-08-23       2.1   0.275528        94       26.5      28.3      25.4
# 9  2025-08-24       2.3   2.538428        91       27.4      30.0      25.5
# 10 2025-08-25       0.0   9.221183        85       28.5      31.4      25.8
# 11 2025-08-26       0.0   9.906117        81       29.2      32.8      26.6
# 12 2025-08-27       0.0   9.988844        84       28.4      31.7      26.4
# 13 2025-08-28       0.0   6.524497        89       27.8      30.2      26.3
# 14 2025-08-29       0.0   7.189942        89       27.9      30.6      26.3
# 15 2025-08-30       0.0   4.428906        90       28.1      30.9      26.3
# 16 2025-08-31       0.0   8.152969        85       29.4      32.6      26.3
# 17 2025-09-01       0.0   8.865056        84       29.6      34.0      26.7
# 18 2025-09-02       0.0   9.728675        84       28.5      31.0      26.7
# 19 2025-09-03       0.0   8.255128        87       28.1      30.1      26.5
# 20 2025-09-04       0.0   9.341281        87       28.5      30.9      26.5
# 21 2025-09-05       0.0  10.319642        85       29.1      32.7      26.9
# 22 2025-09-06       0.0  10.914339        82       29.8      33.3      27.2
# 23 2025-09-07       0.0   6.611489        82       29.5      32.7      27.3
# 24 2025-09-08       0.0   7.998692        83       29.7      33.3      27.6
# 25 2025-09-09       0.0   7.314011        84       29.6      32.7      27.4
# 26 2025-09-10       0.0   7.840681        85       29.4      32.6      27.5
# 27 2025-09-11       0.0   1.872125        87       28.9      32.2      27.1
# 28 2025-09-12       0.0   2.977142        90       28.0      30.2      26.9
# 29 2025-09-13       0.0   3.548639        88       28.3      31.2      26.5
# 30 2025-09-14       0.0   2.658439        92       27.5      29.6      26.0
#
#     Year  Month
# 0   2025      8
# 1   2025      8
# 2   2025      8
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      9
# 18  2025      9
# 19  2025      9
# 20  2025      9
# 21  2025      9
# 22  2025      9
# 23  2025      9
# 24  2025      9
# 25  2025      9
# 26  2025      9
# 27  2025      9
# 28  2025      9
# 29  2025      9
# 30  2025      9

# %%
all_weather_df = pd.concat([dhk_weather_df, cht_weather_df, pat_weather_df])

all_weather_df = (
    all_weather_df.groupby("Date")
    .agg(
        {
            "Rainfall": "mean",
            "Sunshine": "mean",
            "Humidity": "mean",
            "Temp_mean": "mean",
            "Temp_max": "max",
            "Temp_min": "min",
            "Year": "first",
            "Month": "first",
            # "loadshed_prev": "first",
            # "generation_prev": "first",
        }
    )
    .reset_index()
)

all_weather_df
# Out:
#          Date  Rainfall   Sunshine   Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-08-15  0.000000  11.286242  84.333333  28.766667      33.0      26.4
# 1  2025-08-16  0.000000   8.638301  84.333333  28.966667      32.7      26.1
# 2  2025-08-17  0.000000   6.335602  86.000000  28.666667      31.8      27.0
# 3  2025-08-18  0.000000   9.650935  81.666667  28.833333      33.9      26.4
# 4  2025-08-19  0.000000   7.445386  84.333333  28.333333      31.9      26.1
# 5  2025-08-20  0.000000   6.514323  88.000000  27.766667      30.1      25.9
# 6  2025-08-21  0.100000   2.663937  90.666667  27.033333      29.3      25.2
# 7  2025-08-22  0.000000   2.641196  90.333333  27.233333      29.3      25.4
# 8  2025-08-23  1.000000   1.297198  92.000000  26.766667      28.4      25.3
# 9  2025-08-24  0.766667   4.234187  88.666667  27.533333      30.0      25.5
# 10 2025-08-25  0.000000   9.289269  83.000000  28.666667      33.2      25.8
# 11 2025-08-26  0.000000  10.422288  80.666667  29.200000      34.1      26.4
# 12 2025-08-27  0.000000  10.083412  82.666667  28.600000      33.8      26.3
# 13 2025-08-28  0.000000   7.359341  86.000000  28.000000      31.6      26.2
# 14 2025-08-29  0.000000   8.499281  87.000000  28.066667      32.5      26.1
# 15 2025-08-30  0.000000   7.781782  87.000000  28.366667      32.1      26.3
# 16 2025-08-31  0.000000   9.671270  85.333333  29.066667      32.6      26.3
# 17 2025-09-01  0.000000   9.405591  82.666667  29.833333      35.6      26.7
# 18 2025-09-02  0.000000  10.199558  81.333333  28.933333      33.5      26.7
# 19 2025-09-03  0.000000  10.028131  82.666667  28.866667      33.6      26.3
# 20 2025-09-04  0.000000  10.133410  84.666667  28.800000      32.9      26.4
# 21 2025-09-05  0.000000  10.514283  83.000000  29.233333      34.2      26.8
# 22 2025-09-06  0.000000  10.587965  81.666667  29.700000      34.0      26.9
# 23 2025-09-07  0.000000   7.304549  83.000000  29.200000      32.7      26.8
# 24 2025-09-08  0.000000   9.192811  83.333333  29.433333      34.0      27.3
# 25 2025-09-09  0.000000   8.574526  83.333333  29.366667      33.5      26.6
# 26 2025-09-10  0.000000   6.597460  83.333333  29.266667      34.1      26.9
# 27 2025-09-11  0.133333   4.029460  86.000000  28.866667      33.9      26.7
# 28 2025-09-12  0.266667   2.203902  88.333333  28.133333      30.4      26.3
# 29 2025-09-13  0.000000   5.049154  86.000000  28.466667      33.0      26.3
# 30 2025-09-14  0.966667   1.579882  91.666667  27.066667      29.6      25.3
#
#     Year  Month
# 0   2025      8
# 1   2025      8
# 2   2025      8
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      9
# 18  2025      9
# 19  2025      9
# 20  2025      9
# 21  2025      9
# 22  2025      9
# 23  2025      9
# 24  2025      9
# 25  2025      9
# 26  2025      9
# 27  2025      9
# 28  2025      9
# 29  2025      9
# 30  2025      9

# %% [markdown]
# # Get Last Month's Electricity Data

# %%
# from datetime import datetime, timedelta

# yesterday_date = datetime.today() - timedelta(days=1)

# yesterday_date = yesterday_date.strftime("%d-%m-%Y")
# yesterday_date

# %%
import io

all_dfs = []

start_page = 1
end_page = 16

for page in range(start_page, end_page + 1):
    print(f"Fetching page {page}")

    try:
        url = f"https://erp.powergrid.gov.bd/web/generations/view_demand_supply_loadshed?page={page}"
        res = requests.get(url, verify=False)
        res.raise_for_status()
        html = res.text

        tables = pd.read_html(io.StringIO(html))

        page_df = tables[0]

        all_dfs.append(page_df)
    except requests.exceptions.RequestException as e:
        print(e)
# Out:
# Fetching page 1
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 2
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 3
# Fetching page 4
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 5
# Fetching page 6
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 7
# Fetching page 8
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 9
# Fetching page 10
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 11
# Fetching page 12
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 13
# Fetching page 14
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 15
# Fetching page 16
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Need one extra day so that final day's shifted values are not Nan
power_start_date = datetime.strftime(
    datetime.strptime(start_date, "%Y-%m-%d") - timedelta(days=1), "%Y-%m-%d"
)

# %%
power_df = pd.concat(all_dfs, ignore_index=True)
# power_df.columns = power_df.columns.droplevel(0)

power_df = power_df[["Date", "Demand (MW)", "Demand(MW)", "Loadshed"]].copy()

power_df.rename(
    columns={
        "Demand (MW)": "Generation",
        "Demand(MW)": "Demand",
    },
    inplace=True,
)

# Convert MW to GW
power_df["Generation"] = power_df["Generation"] / 1000
power_df["Loadshed"] = power_df["Loadshed"] / 1000
power_df["Demand"] = power_df["Demand"] / 1000

power_df = power_df.groupby("Date").sum().reset_index()

# %%
power_df["Date"] = pd.to_datetime(power_df["Date"], format="%d-%m-%Y")
power_df["Date"] = power_df["Date"].dt.strftime("%Y-%m-%d")
power_df["Date"] = pd.to_datetime(power_df["Date"], format="%Y-%m-%d")

power_df = power_df[
    (power_df["Date"] >= power_start_date) & (power_df["Date"] <= end_date)
]
power_df = power_df.sort_values(by="Date", ascending=True)

power_df
# Out:
#          Date  Generation   Demand  Loadshed
# 14 2025-08-14     341.258  341.399     0.134
# 2   2025      8     362.597  363.993     1.332          350.500          0.550
# 3   2025      8     358.385  359.591     1.152          362.597          1.332
# 4   2025      8     351.223  351.887     0.635          358.385          1.152
# 5   2025      8     342.642  342.729     0.083          351.223          0.635
# 6   2025      8     335.232  335.381     0.142          342.642          0.083
# 7   2025      8     301.593  301.593     0.000          335.232          0.142
# 8   2025      8     311.814  311.814     0.000          301.593          0.000
# 9   2025      8     328.773  328.773     0.000          311.814          0.000
# 10  2025      8     344.547  344.953     0.388          328.773          0.000
# 11  2025      8     361.910  362.399     0.478          344.547          0.388
# 12  2025      8     361.340  361.659     0.305          361.910          0.478
# 13  2025      8     353.398  353.795     0.378          361.340          0.305
# 14  2025      8     322.904  323.012     0.103          353.398          0.378
# 15  2025      8     336.666  336.666     0.000          322.904          0.103
# 16  2025      8     358.298  358.743     0.426          336.666          0.000
# 17  2025      9     365.540  366.966     1.363          358.298          0.426
# 18  2025      9     349.720  350.811     1.042          365.540          1.363
# 19  2025      9     361.091  363.581     2.379          349.720          1.042
# 20  2025      9     361.793  365.041     3.101          361.091          2.379
# 21  2025      9     340.405  342.006     1.531          361.793          3.101
# 22  2025      9     354.368  356.355     1.900          340.405          1.531
# 23  2025      9     366.737  369.016     2.176          354.368          1.900
# 24  2025      9     365.150  372.590     7.104          366.737          2.176
# 25  2025      9     355.290  373.890    17.763          365.150          7.104
# 26  2025      9     362.485  379.060    15.828          355.290         17.763
# 27  2025      9     363.132  367.239     3.921          362.485         15.828
# 28  2025      9     333.467  336.343     2.747          363.132          3.921
# 29  2025      9     346.519  349.549     2.895          333.467          2.747
# 30  2025      9     334.267  336.061     1.713          346.519          2.895

# %%
input_columns = [
    "Rainfall",
    "Sunshine",
    "Humidity",
    "Temp_mean",
    "Temp_max",
    "Temp_min",
    "Year",
    "Month",
    "loadshed_prev",
    "generation_prev",
]

# %% [markdown]
# # Load Model

# %%
import lightgbm as lgb

generation_model = lgb.Booster(model_file="models/generation_lgbm_model.txt")
loadshed_model = lgb.Booster(model_file="models/loadshed_lgbm_model.txt")

# %%
history = []

for idx in range(len(input_df)):
    row = input_df.iloc[idx].to_frame().T.infer_objects()

    generation_pred = generation_model.predict(row[input_columns])[0]
    generation_previous = generation_pred

    loadshed_pred = loadshed_model.predict(row[input_columns])[0]
    loadshed_previous = loadshed_pred

    input_df.loc[idx, "generation_pred"] = generation_pred
    input_df.loc[idx, "loadshed_pred"] = loadshed_pred
    daily = {
        "date": row["Date"].astype(str).values[0],
        "prediction": {
            "generation": generation_pred,
            "loadshed": loadshed_pred,
        },
        "label": {
            "generation": row["Generation"].values[0],
            "loadshed": row["Loadshed"].values[0],
        },
    }
    history.append(daily)

# %%
import matplotlib.pyplot as plt

plt.plot(input_df["Generation"])
plt.plot(input_df["generation_pred"])

# %% [markdown]
# ## Write to prediction.json file

# %%
from pathlib import Path
import json

pred_file = Path("predictions.json")

if pred_file.exists():
    with open(pred_file, "r") as f:
        preds = json.load(f)
else:
    preds = {"forecast": [], "history": []}

preds["history"] = history

try:
    with open(pred_file, "w") as f:
        json.dump(preds, f, indent=2)

    print("Successfully saved predictions")
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# Successfully saved predictions
