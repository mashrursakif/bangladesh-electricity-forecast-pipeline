# %% [markdown]
# # Get Past 1 Month Prediction
#
# **This notebook fetches data of past 1 month, gathers model predictions, and saves to predictions.json as `history`**

# %%
import requests
import pandas as pd
import json
import numpy as np

# %% [markdown]
# # Get Weather Data

# %% [markdown]
# Geo coords for Dhaka, Chittagong, and Patuakhali

# %%
# tuple as (lat, lon)
dhk_coords = (23.7104, 90.40744)
cht_coords = (22.3384, 91.83168)
pat_coords = (22.36833, 90.3458)

# %%
from datetime import datetime, timedelta

start_date = datetime.today() - timedelta(days=31)  # 1 month ago date
start_date = start_date.strftime("%Y-%m-%d")
end_date = datetime.today() - timedelta(days=1)  # yesterday date
end_date = end_date.strftime("%Y-%m-%d")

# %%
start_date
# Out:
# '2025-07-29'

# %%
def get_city_weather(coords, start_date, end_date):
    weather_api_url = f"https://historical-forecast-api.open-meteo.com/v1/forecast?latitude={coords[0]}&longitude={coords[1]}&start_date={start_date}&end_date={end_date}&daily=relative_humidity_2m_mean,temperature_2m_max,temperature_2m_min,temperature_2m_mean,rain_sum,sunshine_duration"
    # weather_api_url = f"https://historical-forecast-api.open-meteo.com/v1/forecast?latitude={coords[0]}&longitude={coords[1]}&start_date={start_date}&end_date={end_date}%hourly=temperature_2m"
    response = requests.get(weather_api_url)

    try:
        response.raise_for_status()
        data = response.json()

        return data
    except requests.exceptions.RequestException as e:
        print(e)

# %%
dhaka_data = get_city_weather(dhk_coords, start_date, end_date)
# dhaka_data

# %%
city_weather_df = pd.DataFrame(
    columns=[
        "Date",  # Remove Date before passed to model
        "Rainfall",
        "Sunshine",
        "Humidity",
        "Temp_mean",
        "Temp_max",
        "Temp_min",
        "Year",
        "Month",
        # "loadshed_prev",
        # "generation_prev",
    ]
)
city_weather_df
# Out:
# Empty DataFrame
# Columns: [Date, Rainfall, Sunshine, Humidity, Temp_mean, Temp_max, Temp_min, Year, Month]
# Index: []

# %%
daily_data = dhaka_data["daily"]

city_weather_df["Date"] = daily_data["time"]
city_weather_df["Date"] = pd.to_datetime(city_weather_df["Date"], format="%Y-%m-%d")
city_weather_df["Year"] = city_weather_df["Date"].dt.year
city_weather_df["Month"] = city_weather_df["Date"].dt.month

city_weather_df["Rainfall"] = daily_data["rain_sum"]
city_weather_df["Sunshine"] = daily_data["sunshine_duration"]
city_weather_df["Sunshine"] = city_weather_df["Sunshine"] / (60 * 60)
city_weather_df["Humidity"] = daily_data["relative_humidity_2m_mean"]

city_weather_df["Temp_mean"] = daily_data["temperature_2m_mean"]
city_weather_df["Temp_max"] = daily_data["temperature_2m_max"]
city_weather_df["Temp_min"] = daily_data["temperature_2m_min"]

city_weather_df
# Out:
#          Date  Rainfall   Sunshine  Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-07-29       0.0   4.805611        90       27.6      30.7      26.1
# 1  2025-07-30       0.1   5.285469        89       27.6      30.5      26.0
# 2  2025-07-31       0.7   0.244497        93       27.1      29.4      26.0
# 3  2025-08-01       0.0   4.141239        90       28.0      31.6      26.3
# 4  2025-08-02       0.0   4.494117        89       28.4      31.9      26.7
# 5  2025-08-03       0.0   5.759817        87       28.9      32.9      26.8
# 6  2025-08-04       0.9   3.831717        92       28.0      29.8      26.3
# 7  2025-08-05       0.0   1.178514        93       27.2      30.3      25.7
# 8  2025-08-06       0.0   5.884031        88       27.8      30.9      25.9
# 9  2025-08-07       0.0   2.812619        89       27.7      30.2      25.8
# 10 2025-08-08       0.0   1.157369        92       26.6      28.2      25.3
# 11 2025-08-09       0.0  10.940125        86       28.1      31.6      25.6
# 12 2025-08-10       0.0  10.318069        80       29.6      33.4      26.2
# 13 2025-08-11       0.0  10.850103        77       30.5      35.0      27.2
# 14 2025-08-12       0.0   6.296903        81       30.1      33.8      27.4
# 15 2025-08-13       0.0   0.405972        89       28.1      30.1      26.3
# 16 2025-08-14       0.0   4.220486        88       28.1      31.5      26.1
# 17 2025-08-15       0.0  12.000000        83       29.3      33.0      26.4
# 18 2025-08-16       0.0   7.457553        83       29.4      32.7      26.1
# 19 2025-08-17       0.0   5.805636        87       28.9      31.4      27.1
# 20 2025-08-18       0.0  11.005475        78       29.6      33.9      26.5
# 21 2025-08-19       0.0   9.260372        84       28.4      31.9      26.1
# 22 2025-08-20       0.0   5.320253        89       27.6      30.1      25.9
# 23 2025-08-21       0.0   1.424925        91       26.9      29.3      25.2
# 24 2025-08-22       0.0   2.783719        89       27.2      29.3      25.4
# 25 2025-08-23       0.0   1.357611        92       26.7      28.4      25.3
# 26 2025-08-24       0.0   3.094358        89       27.5      29.8      25.7
# 27 2025-08-25       0.0   9.554189        79       29.4      33.2      25.9
# 28 2025-08-26       0.0  11.991942        77       30.0      34.1      26.4
# 29 2025-08-27       0.0  10.933561        80       29.3      33.8      26.3
# 30 2025-08-28       0.0   7.762828        85       28.2      31.6      26.2
#
#     Year  Month
# 0   2025      7
# 1   2025      7
# 2   2025      7
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      8
# 18  2025      8
# 19  2025      8
# 20  2025      8
# 21  2025      8
# 22  2025      8
# 23  2025      8
# 24  2025      8
# 25  2025      8
# 26  2025      8
# 27  2025      8
# 28  2025      8
# 29  2025      8
# 30  2025      8

# %%
def get_city_weather_df(daily_data):
    city_df = pd.DataFrame(
        columns=[
            "Date",  # Remove Date before passed to model
            "Rainfall",
            "Sunshine",
            "Humidity",
            "Temp_mean",
            "Temp_max",
            "Temp_min",
            "Year",
            "Month",
            # "loadshed_prev",
            # "generation_prev",
        ]
    )

    city_df["Date"] = daily_data["time"]
    city_df["Date"] = pd.to_datetime(city_df["Date"], format="%Y-%m-%d")
    city_df["Year"] = city_df["Date"].dt.year
    city_df["Month"] = city_df["Date"].dt.month

    city_df["Rainfall"] = daily_data["rain_sum"]
    city_df["Sunshine"] = daily_data["sunshine_duration"]
    # Convert seconds to hours
    city_df["Sunshine"] = city_df["Sunshine"] / (60 * 60)
    city_df["Humidity"] = daily_data["relative_humidity_2m_mean"]

    city_df["Temp_mean"] = daily_data["temperature_2m_mean"]
    city_df["Temp_max"] = daily_data["temperature_2m_max"]
    city_df["Temp_min"] = daily_data["temperature_2m_min"]

    return city_df

# %% [markdown]
# ## Get weather data of all locations

# %%
dhk_data = get_city_weather(dhk_coords, start_date, end_date)
dhk_weather_df = get_city_weather_df(dhk_data["daily"])
dhk_weather_df
# Out:
#          Date  Rainfall   Sunshine  Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-07-29       0.0   4.805611        90       27.6      30.7      26.1
# 1  2025-07-30       0.1   5.285469        89       27.6      30.5      26.0
# 2  2025-07-31       0.7   0.244497        93       27.1      29.4      26.0
# 3  2025-08-01       0.0   4.141239        90       28.0      31.6      26.3
# 4  2025-08-02       0.0   4.494117        89       28.4      31.9      26.7
# 5  2025-08-03       0.0   5.759817        87       28.9      32.9      26.8
# 6  2025-08-04       0.9   3.831717        92       28.0      29.8      26.3
# 7  2025-08-05       0.0   1.178514        93       27.2      30.3      25.7
# 8  2025-08-06       0.0   5.884031        88       27.8      30.9      25.9
# 9  2025-08-07       0.0   2.812619        89       27.7      30.2      25.8
# 10 2025-08-08       0.0   1.157369        92       26.6      28.2      25.3
# 11 2025-08-09       0.0  10.940125        86       28.1      31.6      25.6
# 12 2025-08-10       0.0  10.318069        80       29.6      33.4      26.2
# 13 2025-08-11       0.0  10.850103        77       30.5      35.0      27.2
# 14 2025-08-12       0.0   6.296903        81       30.1      33.8      27.4
# 15 2025-08-13       0.0   0.405972        89       28.1      30.1      26.3
# 16 2025-08-14       0.0   4.220486        88       28.1      31.5      26.1
# 17 2025-08-15       0.0  12.000000        83       29.3      33.0      26.4
# 18 2025-08-16       0.0   7.457553        83       29.4      32.7      26.1
# 19 2025-08-17       0.0   5.805636        87       28.9      31.4      27.1
# 20 2025-08-18       0.0  11.005475        78       29.6      33.9      26.5
# 21 2025-08-19       0.0   9.260372        84       28.4      31.9      26.1
# 22 2025-08-20       0.0   5.320253        89       27.6      30.1      25.9
# 23 2025-08-21       0.0   1.424925        91       26.9      29.3      25.2
# 24 2025-08-22       0.0   2.783719        89       27.2      29.3      25.4
# 25 2025-08-23       0.0   1.357611        92       26.7      28.4      25.3
# 26 2025-08-24       0.0   3.094358        89       27.5      29.8      25.7
# 27 2025-08-25       0.0   9.554189        79       29.4      33.2      25.9
# 28 2025-08-26       0.0  11.991942        77       30.0      34.1      26.4
# 29 2025-08-27       0.0  10.933561        80       29.3      33.8      26.3
# 30 2025-08-28       0.0   7.762828        85       28.2      31.6      26.2
#
#     Year  Month
# 0   2025      7
# 1   2025      7
# 2   2025      7
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      8
# 18  2025      8
# 19  2025      8
# 20  2025      8
# 21  2025      8
# 22  2025      8
# 23  2025      8
# 24  2025      8
# 25  2025      8
# 26  2025      8
# 27  2025      8
# 28  2025      8
# 29  2025      8
# 30  2025      8

# %%
cht_data = get_city_weather(cht_coords, start_date, end_date)
cht_weather_df = get_city_weather_df(cht_data["daily"])
cht_weather_df
# Out:
#          Date  Rainfall   Sunshine  Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-07-29       0.0   0.199089        90       27.3      27.8      26.7
# 1  2025-07-30       2.4   0.000000        89       27.3      28.0      26.5
# 2  2025-07-31       0.3   0.115594        91       27.3      28.3      26.5
# 3  2025-08-01       0.0   5.133656        91       27.6      28.2      26.6
# 4  2025-08-02       0.0   0.943383        91       27.8      28.4      27.3
# 5  2025-08-03       0.0   9.176200        89       27.9      28.6      26.9
# 6  2025-08-04       0.0   8.194686        89       27.9      28.5      26.8
# 7  2025-08-05       0.1   7.145914        87       28.2      29.1      27.0
# 8  2025-08-06       0.6   6.204339        89       27.6      28.4      26.8
# 9  2025-08-07       0.0   1.117558        89       27.5      28.0      26.8
# 10 2025-08-08       0.0   1.894481        89       26.9      27.5      26.4
# 11 2025-08-09       0.0   9.084819        85       27.8      28.7      26.8
# 12 2025-08-10       0.0  11.864294        86       28.4      29.0      27.3
# 13 2025-08-11       0.0  10.417586        88       28.4      29.1      27.3
# 14 2025-08-12       0.0   6.951611        88       28.4      29.0      27.5
# 15 2025-08-13       0.0   4.170947        85       28.3      29.4      27.6
# 16 2025-08-14       0.0   7.630067        86       28.2      29.6      27.2
# 17 2025-08-15       0.0  10.091100        85       28.2      29.0      27.1
# 18 2025-08-16       0.0   8.674914        86       28.1      29.0      26.9
# 19 2025-08-17       0.0   6.795431        86       28.3      29.0      27.1
# 20 2025-08-18       0.0   8.420267        83       28.5      30.3      27.3
# 21 2025-08-19       0.0   7.742228        82       28.6      29.6      27.5
# 22 2025-08-20       0.0   9.287472        85       28.1      29.4      26.9
# 23 2025-08-21       0.0   6.566886        88       27.4      28.1      26.4
# 24 2025-08-22       0.0   3.369714        90       27.2      28.1      26.3
# 25 2025-08-23       0.9   2.258456        90       27.1      28.0      26.5
# 26 2025-08-24       0.0   7.069775        86       27.7      28.2      27.1
# 27 2025-08-25       0.0   9.092433        85       28.1      28.9      26.9
# 28 2025-08-26       0.0   9.368806        84       28.4      29.6      26.9
# 29 2025-08-27       0.0   9.327831        84       28.1      29.4      26.8
# 30 2025-08-28       0.0   7.790697        84       28.0      28.6      26.8
#
#     Year  Month
# 0   2025      7
# 1   2025      7
# 2   2025      7
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      8
# 18  2025      8
# 19  2025      8
# 20  2025      8
# 21  2025      8
# 22  2025      8
# 23  2025      8
# 24  2025      8
# 25  2025      8
# 26  2025      8
# 27  2025      8
# 28  2025      8
# 29  2025      8
# 30  2025      8

# %%
pat_data = get_city_weather(pat_coords, start_date, end_date)
pat_weather_df = get_city_weather_df(pat_data["daily"])
pat_weather_df
# Out:
#          Date  Rainfall   Sunshine  Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-07-29       0.7   0.000000        95       27.0      28.1      26.1
# 1  2025-07-30      12.0   0.000000        94       27.0      29.1      26.1
# 2  2025-07-31       1.9   0.000000        93       27.3      28.2      26.6
# 3  2025-08-01       0.0   4.315425        91       28.6      31.5      26.9
# 4  2025-08-02       0.0   6.525975        88       29.1      32.5      27.1
# 5  2025-08-03       0.0   6.399994        86       29.2      31.7      27.5
# 6  2025-08-04       0.0  10.695436        87       29.2      31.9      27.3
# 7  2025-08-05       0.0   9.589525        85       29.4      32.6      27.0
# 8  2025-08-06       0.6   2.230311        89       28.1      30.1      26.8
# 9  2025-08-07       0.0   2.007642        90       27.7      30.4      26.1
# 10 2025-08-08       0.0   1.288308        90       27.0      28.5      26.1
# 11 2025-08-09       0.0   4.724094        87       27.9      30.1      26.1
# 12 2025-08-10       0.0  11.115944        83       29.3      32.6      27.1
# 13 2025-08-11       0.0   7.857278        84       29.4      33.1      27.2
# 14 2025-08-12       0.0   5.336733        83       29.8      33.4      27.5
# 15 2025-08-13       0.0   1.060189        87       28.4      30.7      26.7
# 16 2025-08-14       0.0   6.453100        88       28.1      30.6      26.6
# 17 2025-08-15       0.0  11.767625        85       28.8      31.6      26.7
# 18 2025-08-16       0.0   9.782436        84       29.4      32.7      26.8
# 19 2025-08-17       0.0   6.405739        85       28.8      31.8      27.0
# 20 2025-08-18       0.0   9.527064        84       28.4      30.7      26.4
# 21 2025-08-19       0.0   5.333558        87       28.0      31.2      26.4
# 22 2025-08-20       0.0   4.935244        90       27.6      29.6      26.3
# 23 2025-08-21       0.3   0.000000        93       26.8      28.1      25.7
# 24 2025-08-22       0.0   1.770156        92       27.3      29.2      26.1
# 25 2025-08-23       2.1   0.275528        94       26.5      28.3      25.4
# 26 2025-08-24       2.3   2.538428        91       27.4      30.0      25.5
# 27 2025-08-25       0.0   9.221183        85       28.5      31.4      25.8
# 28 2025-08-26       0.0   9.906117        81       29.2      32.8      26.6
# 29 2025-08-27       0.0   9.988844        84       28.4      31.7      26.4
# 30 2025-08-28       0.0   6.524497        89       27.8      30.2      26.3
#
#     Year  Month
# 0   2025      7
# 1   2025      7
# 2   2025      7
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      8
# 18  2025      8
# 19  2025      8
# 20  2025      8
# 21  2025      8
# 22  2025      8
# 23  2025      8
# 24  2025      8
# 25  2025      8
# 26  2025      8
# 27  2025      8
# 28  2025      8
# 29  2025      8
# 30  2025      8

# %%
all_weather_df = pd.concat([dhk_weather_df, cht_weather_df, pat_weather_df])

all_weather_df = (
    all_weather_df.groupby("Date")
    .agg(
        {
            "Rainfall": "mean",
            "Sunshine": "mean",
            "Humidity": "mean",
            "Temp_mean": "mean",
            "Temp_max": "max",
            "Temp_min": "min",
            "Year": "first",
            "Month": "first",
            # "loadshed_prev": "first",
            # "generation_prev": "first",
        }
    )
    .reset_index()
)

all_weather_df
# Out:
#          Date  Rainfall   Sunshine   Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-07-29  0.233333   1.668233  91.666667  27.300000      30.7      26.1
# 1  2025-07-30  4.833333   1.761823  90.666667  27.300000      30.5      26.0
# 2  2025-07-31  0.966667   0.120031  92.333333  27.233333      29.4      26.0
# 3  2025-08-01  0.000000   4.530106  90.666667  28.066667      31.6      26.3
# 4  2025-08-02  0.000000   3.987825  89.333333  28.433333      32.5      26.7
# 5  2025-08-03  0.000000   7.112004  87.333333  28.666667      32.9      26.8
# 6  2025-08-04  0.300000   7.573946  89.333333  28.366667      31.9      26.3
# 7  2025-08-05  0.033333   5.971318  88.333333  28.266667      32.6      25.7
# 8  2025-08-06  0.400000   4.772894  88.666667  27.833333      30.9      25.9
# 9  2025-08-07  0.000000   1.979273  89.333333  27.633333      30.4      25.8
# 10 2025-08-08  0.000000   1.446719  90.333333  26.833333      28.5      25.3
# 11 2025-08-09  0.000000   8.249680  86.000000  27.933333      31.6      25.6
# 12 2025-08-10  0.000000  11.099436  83.000000  29.100000      33.4      26.2
# 13 2025-08-11  0.000000   9.708322  83.000000  29.433333      35.0      27.2
# 14 2025-08-12  0.000000   6.195082  84.000000  29.433333      33.8      27.4
# 15 2025-08-13  0.000000   1.879036  87.000000  28.266667      30.7      26.3
# 16 2025-08-14  0.000000   6.101218  87.333333  28.133333      31.5      26.1
# 17 2025-08-15  0.000000  11.286242  84.333333  28.766667      33.0      26.4
# 18 2025-08-16  0.000000   8.638301  84.333333  28.966667      32.7      26.1
# 19 2025-08-17  0.000000   6.335602  86.000000  28.666667      31.8      27.0
# 20 2025-08-18  0.000000   9.650935  81.666667  28.833333      33.9      26.4
# 21 2025-08-19  0.000000   7.445386  84.333333  28.333333      31.9      26.1
# 22 2025-08-20  0.000000   6.514323  88.000000  27.766667      30.1      25.9
# 23 2025-08-21  0.100000   2.663937  90.666667  27.033333      29.3      25.2
# 24 2025-08-22  0.000000   2.641196  90.333333  27.233333      29.3      25.4
# 25 2025-08-23  1.000000   1.297198  92.000000  26.766667      28.4      25.3
# 26 2025-08-24  0.766667   4.234187  88.666667  27.533333      30.0      25.5
# 27 2025-08-25  0.000000   9.289269  83.000000  28.666667      33.2      25.8
# 28 2025-08-26  0.000000  10.422288  80.666667  29.200000      34.1      26.4
# 29 2025-08-27  0.000000  10.083412  82.666667  28.600000      33.8      26.3
# 30 2025-08-28  0.000000   7.359341  86.000000  28.000000      31.6      26.2
#
#     Year  Month
# 0   2025      7
# 1   2025      7
# 2   2025      7
# 3   2025      8
# 4   2025      8
# 5   2025      8
# 6   2025      8
# 7   2025      8
# 8   2025      8
# 9   2025      8
# 10  2025      8
# 11  2025      8
# 12  2025      8
# 13  2025      8
# 14  2025      8
# 15  2025      8
# 16  2025      8
# 17  2025      8
# 18  2025      8
# 19  2025      8
# 20  2025      8
# 21  2025      8
# 22  2025      8
# 23  2025      8
# 24  2025      8
# 25  2025      8
# 26  2025      8
# 27  2025      8
# 28  2025      8
# 29  2025      8
# 30  2025      8

# %% [markdown]
# # Get Last Month's Electricity Data

# %%
# from datetime import datetime, timedelta

# yesterday_date = datetime.today() - timedelta(days=1)

# yesterday_date = yesterday_date.strftime("%d-%m-%Y")
# yesterday_date

# %%
import io

all_dfs = []

start_page = 1
end_page = 16

for page in range(start_page, end_page + 1):
    print(f"Fetching page {page}")

    try:
        url = f"https://erp.pgcb.gov.bd/w/generations/view_generations?page={page}"
        res = requests.get(url, verify=False)
        res.raise_for_status()
        html = res.text

        tables = pd.read_html(io.StringIO(html))

        page_df = tables[0]

        all_dfs.append(page_df)
    except requests.exceptions.RequestException as e:
        print(e)
# Out:
# Fetching page 1
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 2
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 3
# Fetching page 4
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 5
# Fetching page 6
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 7
# Fetching page 8
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 9
# Fetching page 10
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 11
# Fetching page 12
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 13
# Fetching page 14
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Fetching page 15
# Fetching page 16
# /home/mashrur/anaconda3/envs/my_env/lib/python3.12/site-packages/urllib3/connectionpool.py:2303: InsecureRequestWarning: Unverified HTTPS request is being made to host 'erp.pgcb.gov.bd'. Adding certificate verification is strongly advised. See: https://urllib3future.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Need one extra day so that final day's shifted values are not Nan
power_start_date = datetime.strftime(
    datetime.strptime(start_date, "%Y-%m-%d") - timedelta(days=1), "%Y-%m-%d"
)

# %%
power_df = pd.concat(all_dfs, ignore_index=True)
power_df.columns = power_df.columns.droplevel(0)

power_df = power_df[["Date", "Generation(MW)", "Demand(MW)", "Loadshed"]].copy()

power_df.rename(
    columns={
        "Generation(MW)": "Generation",
        "Demand(MW)": "Demand",
    },
    inplace=True,
)

# Convert MW to GW
power_df["Generation"] = power_df["Generation"] / 1000
power_df["Loadshed"] = power_df["Loadshed"] / 1000
power_df["Demand"] = power_df["Demand"] / 1000

power_df = power_df.groupby("Date").sum().reset_index()

# %%
power_df["Date"] = pd.to_datetime(power_df["Date"], format="%d-%m-%Y")
power_df["Date"] = power_df["Date"].dt.strftime("%Y-%m-%d")
power_df["Date"] = pd.to_datetime(power_df["Date"], format="%Y-%m-%d")

power_df = power_df[
    (power_df["Date"] >= power_start_date) & (power_df["Date"] <= end_date)
]
power_df = power_df.sort_values(by="Date", ascending=True)

power_df
# Out:
#          Date  Generation   Demand  Loadshed
# 28 2025-07-28     340.058  340.557     0.477
# 30 2025-07-29     337.235  338.068     0.795
# 32 2025-07-30     343.849  344.650     0.765
# 33 2025-07-31     333.455  333.943     0.466
# 0  2025-08-01     306.883  306.939     0.054
# 1  2025-08-02     333.336  333.424     0.084
# 2  2025-08-03     342.033  342.170     0.129
# 3  2025-08-04     333.394  333.394     0.000
# 4  2025-08-05     294.485  295.198     0.680
# 5  2025-08-06     326.322  327.296     0.930
# 6  2025-08-07     337.360  337.867     0.485
# 7  2025-08-08     296.527  296.527     0.000
# 8  2025-08-09     315.874  316.051     0.169
# 9  2025-08-10     345.068  345.374     0.294
# 10 2025-08-11     358.986  359.973     0.941
# 11 2025-08-12     365.599  366.099     0.479
# 12 2025-08-13     343.717  343.866     0.142
# 13 2025-08-14     341.258  341.399     0.134
# 14 2025-08-15     326.507  326.605     0.094
# 15 2025-08-16     350.500  351.075     0.550
# 16 2025-08-17     362.597  363.993     1.332
# 17 2025-08-18     358.385  359.591     1.152
# 18 2025-08-19     351.223  351.887     0.635
# 19 2025-08-20     342.642  342.729     0.083
# 20 2025-08-21     335.232  335.381     0.142
# 21 2025-08-22     301.593  301.593     0.000
# 22 2025-08-23     311.814  311.814     0.000
# 23 2025-08-24     328.773  328.773     0.000
# 24 2025-08-25     344.547  344.953     0.388
# 25 2025-08-26     361.910  362.399     0.478
# 27 2025-08-27     361.340  361.659     0.305
# 29 2025-08-28     353.398  353.795     0.378

# %%
power_df["generation_prev"] = power_df["Generation"].shift(1)
power_df["loadshed_prev"] = power_df["Loadshed"].shift(1)

power_df = power_df.iloc[1:].reset_index(drop=True)

# power_df = power_df[["Date", "generation_prev", "loadshed_prev"]]
power_df
# Out:
#          Date  Generation   Demand  Loadshed  generation_prev  loadshed_prev
# 0  2025-07-30     343.849  344.650     0.765          337.235          0.795
# 1  2025-07-31     333.455  333.943     0.466          343.849          0.765
# 2  2025-08-01     306.883  306.939     0.054          333.455          0.466
# 3  2025-08-02     333.336  333.424     0.084          306.883          0.054
# 4  2025-08-03     342.033  342.170     0.129          333.336          0.084
# 5  2025-08-04     333.394  333.394     0.000          342.033          0.129
# 6  2025-08-05     294.485  295.198     0.680          333.394          0.000
# 7  2025-08-06     326.322  327.296     0.930          294.485          0.680
# 8  2025-08-07     337.360  337.867     0.485          326.322          0.930
# 9  2025-08-08     296.527  296.527     0.000          337.360          0.485
# 10 2025-08-09     315.874  316.051     0.169          296.527          0.000
# 11 2025-08-10     345.068  345.374     0.294          315.874          0.169
# 12 2025-08-11     358.986  359.973     0.941          345.068          0.294
# 13 2025-08-12     365.599  366.099     0.479          358.986          0.941
# 14 2025-08-13     343.717  343.866     0.142          365.599          0.479
# 15 2025-08-14     341.258  341.399     0.134          343.717          0.142
# 16 2025-08-15     326.507  326.605     0.094          341.258          0.134
# 17 2025-08-16     350.500  351.075     0.550          326.507          0.094
# 18 2025-08-17     362.597  363.993     1.332          350.500          0.550
# 19 2025-08-18     358.385  359.591     1.152          362.597          1.332
# 20 2025-08-19     351.223  351.887     0.635          358.385          1.152
# 21 2025-08-20     342.642  342.729     0.083          351.223          0.635
# 22 2025-08-21     335.232  335.381     0.142          342.642          0.083
# 23 2025-08-22     301.593  301.593     0.000          335.232          0.142
# 24 2025-08-23     311.814  311.814     0.000          301.593          0.000
# 25 2025-08-24     328.773  328.773     0.000          311.814          0.000
# 26 2025-08-25     344.547  344.953     0.388          328.773          0.000
# 27 2025-08-26     361.910  362.399     0.478          344.547          0.388
# 28 2025-08-27     361.340  361.659     0.305          361.910          0.478
# 29 2025-08-28     353.398  353.795     0.378          361.340          0.305

# %%
input_df = all_weather_df.copy()

input_df = pd.merge(input_df, power_df, on="Date")
input_df
# Out:
#          Date  Rainfall   Sunshine   Humidity  Temp_mean  Temp_max  Temp_min  \
# 0  2025-07-30  4.833333   1.761823  90.666667  27.300000      30.5      26.0
# 1  2025-07-31  0.966667   0.120031  92.333333  27.233333      29.4      26.0
# 2  2025-08-01  0.000000   4.530106  90.666667  28.066667      31.6      26.3
# 3  2025-08-02  0.000000   3.987825  89.333333  28.433333      32.5      26.7
# 4  2025-08-03  0.000000   7.112004  87.333333  28.666667      32.9      26.8
# 5  2025-08-04  0.300000   7.573946  89.333333  28.366667      31.9      26.3
# 6  2025-08-05  0.033333   5.971318  88.333333  28.266667      32.6      25.7
# 7  2025-08-06  0.400000   4.772894  88.666667  27.833333      30.9      25.9
# 8  2025-08-07  0.000000   1.979273  89.333333  27.633333      30.4      25.8
# 9  2025-08-08  0.000000   1.446719  90.333333  26.833333      28.5      25.3
# 10 2025-08-09  0.000000   8.249680  86.000000  27.933333      31.6      25.6
# 11 2025-08-10  0.000000  11.099436  83.000000  29.100000      33.4      26.2
# 12 2025-08-11  0.000000   9.708322  83.000000  29.433333      35.0      27.2
# 13 2025-08-12  0.000000   6.195082  84.000000  29.433333      33.8      27.4
# 14 2025-08-13  0.000000   1.879036  87.000000  28.266667      30.7      26.3
# 15 2025-08-14  0.000000   6.101218  87.333333  28.133333      31.5      26.1
# 16 2025-08-15  0.000000  11.286242  84.333333  28.766667      33.0      26.4
# 17 2025-08-16  0.000000   8.638301  84.333333  28.966667      32.7      26.1
# 18 2025-08-17  0.000000   6.335602  86.000000  28.666667      31.8      27.0
# 19 2025-08-18  0.000000   9.650935  81.666667  28.833333      33.9      26.4
# 20 2025-08-19  0.000000   7.445386  84.333333  28.333333      31.9      26.1
# 21 2025-08-20  0.000000   6.514323  88.000000  27.766667      30.1      25.9
# 22 2025-08-21  0.100000   2.663937  90.666667  27.033333      29.3      25.2
# 23 2025-08-22  0.000000   2.641196  90.333333  27.233333      29.3      25.4
# 24 2025-08-23  1.000000   1.297198  92.000000  26.766667      28.4      25.3
# 25 2025-08-24  0.766667   4.234187  88.666667  27.533333      30.0      25.5
# 26 2025-08-25  0.000000   9.289269  83.000000  28.666667      33.2      25.8
# 27 2025-08-26  0.000000  10.422288  80.666667  29.200000      34.1      26.4
# 28 2025-08-27  0.000000  10.083412  82.666667  28.600000      33.8      26.3
# 29 2025-08-28  0.000000   7.359341  86.000000  28.000000      31.6      26.2
#
#     Year  Month  Generation   Demand  Loadshed  generation_prev  loadshed_prev
# 0   2025      7     343.849  344.650     0.765          337.235          0.795
# 1   2025      7     333.455  333.943     0.466          343.849          0.765
# 2   2025      8     306.883  306.939     0.054          333.455          0.466
# 3   2025      8     333.336  333.424     0.084          306.883          0.054
# 4   2025      8     342.033  342.170     0.129          333.336          0.084
# 5   2025      8     333.394  333.394     0.000          342.033          0.129
# 6   2025      8     294.485  295.198     0.680          333.394          0.000
# 7   2025      8     326.322  327.296     0.930          294.485          0.680
# 8   2025      8     337.360  337.867     0.485          326.322          0.930
# 9   2025      8     296.527  296.527     0.000          337.360          0.485
# 10  2025      8     315.874  316.051     0.169          296.527          0.000
# 11  2025      8     345.068  345.374     0.294          315.874          0.169
# 12  2025      8     358.986  359.973     0.941          345.068          0.294
# 13  2025      8     365.599  366.099     0.479          358.986          0.941
# 14  2025      8     343.717  343.866     0.142          365.599          0.479
# 15  2025      8     341.258  341.399     0.134          343.717          0.142
# 16  2025      8     326.507  326.605     0.094          341.258          0.134
# 17  2025      8     350.500  351.075     0.550          326.507          0.094
# 18  2025      8     362.597  363.993     1.332          350.500          0.550
# 19  2025      8     358.385  359.591     1.152          362.597          1.332
# 20  2025      8     351.223  351.887     0.635          358.385          1.152
# 21  2025      8     342.642  342.729     0.083          351.223          0.635
# 22  2025      8     335.232  335.381     0.142          342.642          0.083
# 23  2025      8     301.593  301.593     0.000          335.232          0.142
# 24  2025      8     311.814  311.814     0.000          301.593          0.000
# 25  2025      8     328.773  328.773     0.000          311.814          0.000
# 26  2025      8     344.547  344.953     0.388          328.773          0.000
# 27  2025      8     361.910  362.399     0.478          344.547          0.388
# 28  2025      8     361.340  361.659     0.305          361.910          0.478
# 29  2025      8     353.398  353.795     0.378          361.340          0.305

# %% [markdown]
# # Load Model

# %%
import lightgbm as lgb

generation_model = lgb.Booster(model_file="models/generation_lgbm_model.txt")
loadshed_model = lgb.Booster(model_file="models/loadshed_lgbm_model.txt")

# %%
history = []

for idx in range(len(input_df)):
    row = input_df.iloc[idx].to_frame().T.infer_objects()

    generation_pred = generation_model.predict(
        row.drop(columns=["Date", "Generation", "Demand", "Loadshed"])
    )[0]
    generation_previous = generation_pred

    loadshed_pred = loadshed_model.predict(
        row.drop(columns=["Date", "Generation", "Demand", "Loadshed"])
    )[0]
    loadshed_previous = loadshed_pred

    daily = {
        "date": row["Date"].astype(str).values[0],
        "prediction": {
            "generation": generation_pred,
            "loadshed": loadshed_pred,
        },
        "label": {
            "generation": row["Generation"].values[0],
            "loadshed": row["Loadshed"].values[0],
        },
    }
    history.append(daily)

# %%
history
# Out:
# [{'date': '2025-07-30',
#   'prediction': {'generation': 181.33953357660496,
#    'loadshed': 1.1985977559148289},
#   'label': {'generation': 343.849, 'loadshed': 0.765}},
#  {'date': '2025-07-31',
#   'prediction': {'generation': 182.03576950013633,
#    'loadshed': 0.7035800571368294},
#   'label': {'generation': 333.455, 'loadshed': 0.46599999999999997}},
#  {'date': '2025-08-01',
#   'prediction': {'generation': 181.94742097634003,
#    'loadshed': 1.2822423997400394},
#   'label': {'generation': 306.883, 'loadshed': 0.054000000000000006}},
#  {'date': '2025-08-02',
#   'prediction': {'generation': 183.05844272529734,
#    'loadshed': 4.9359197879883645},
#   'label': {'generation': 333.336, 'loadshed': 0.08399999999999999}},
#  {'date': '2025-08-03',
#   'prediction': {'generation': 185.958510173318,
#    'loadshed': 4.930823123351596},
#   'label': {'generation': 342.033, 'loadshed': 0.129}},
#  {'date': '2025-08-04',
#   'prediction': {'generation': 185.58985460544213,
#    'loadshed': 1.1503643340536647},
#   'label': {'generation': 333.394, 'loadshed': 0.0}},
#  {'date': '2025-08-05',
#   'prediction': {'generation': 183.5642162091283,
#    'loadshed': 4.900895674819896},
#   'label': {'generation': 294.485, 'loadshed': 0.68}},
#  {'date': '2025-08-06',
#   'prediction': {'generation': 182.8487874310322,
#    'loadshed': 1.2528246075346974},
#   'label': {'generation': 326.322, 'loadshed': 0.9299999999999999}},
#  {'date': '2025-08-07',
#   'prediction': {'generation': 183.6731593282672,
#    'loadshed': 1.2524870411587552},
#   'label': {'generation': 337.36, 'loadshed': 0.485}},
#  {'date': '2025-08-08',
#   'prediction': {'generation': 182.81256359257068,
#    'loadshed': 0.7053478103017001},
#   'label': {'generation': 296.527, 'loadshed': 0.0}},
#  {'date': '2025-08-09',
#   'prediction': {'generation': 190.55527173947158,
#    'loadshed': 1.8891204986950092},
#   'label': {'generation': 315.874, 'loadshed': 0.16899999999999998}},
#  {'date': '2025-08-10',
#   'prediction': {'generation': 197.528232595956,
#    'loadshed': 5.581589317515161},
#   'label': {'generation': 345.068, 'loadshed': 0.294}},
#  {'date': '2025-08-11',
#   'prediction': {'generation': 199.4818722245204,
#    'loadshed': 5.599620389545318},
#   'label': {'generation': 358.986, 'loadshed': 0.9410000000000001}},
#  {'date': '2025-08-12',
#   'prediction': {'generation': 187.46747587215884, 'loadshed': 4.934669469426},
#   'label': {'generation': 365.599, 'loadshed': 0.479}},
#  {'date': '2025-08-13',
#   'prediction': {'generation': 182.77281129756534,
#    'loadshed': 1.2622758773521108},
#   'label': {'generation': 343.717, 'loadshed': 0.142}},
#  {'date': '2025-08-14',
#   'prediction': {'generation': 183.31073486428798,
#    'loadshed': 1.247039858618026},
#   'label': {'generation': 341.258, 'loadshed': 0.134}},
#  {'date': '2025-08-15',
#   'prediction': {'generation': 197.58027767690263,
#    'loadshed': 5.57296868126824},
#   'label': {'generation': 326.507, 'loadshed': 0.094}},
#  {'date': '2025-08-16',
#   'prediction': {'generation': 198.0913647366773,
#    'loadshed': 5.573456529292152},
#   'label': {'generation': 350.5, 'loadshed': 0.55}},
#  {'date': '2025-08-17',
#   'prediction': {'generation': 186.955547950898,
#    'loadshed': 1.094639792865225},
#   'label': {'generation': 362.597, 'loadshed': 1.332}},
#  {'date': '2025-08-18',
#   'prediction': {'generation': 197.49005520471553,
#    'loadshed': 5.5694433990816306},
#   'label': {'generation': 358.385, 'loadshed': 1.1520000000000001}},
#  {'date': '2025-08-19',
#   'prediction': {'generation': 187.6000497204218,
#    'loadshed': 1.2007457448370427},
#   'label': {'generation': 351.223, 'loadshed': 0.635}},
#  {'date': '2025-08-20',
#   'prediction': {'generation': 186.50362897080458,
#    'loadshed': 1.239439891651217},
#   'label': {'generation': 342.642, 'loadshed': 0.083}},
#  {'date': '2025-08-21',
#   'prediction': {'generation': 182.250810000185,
#    'loadshed': 0.6759300180963583},
#   'label': {'generation': 335.232, 'loadshed': 0.14200000000000002}},
#  {'date': '2025-08-22',
#   'prediction': {'generation': 184.60706148696036,
#    'loadshed': 0.7053478103017001},
#   'label': {'generation': 301.593, 'loadshed': 0.0}},
#  {'date': '2025-08-23',
#   'prediction': {'generation': 182.7539765218551,
#    'loadshed': 0.6759300180963583},
#   'label': {'generation': 311.814, 'loadshed': 0.0}},
#  {'date': '2025-08-24',
#   'prediction': {'generation': 184.69515302665107,
#    'loadshed': 0.6927753337661448},
#   'label': {'generation': 328.773, 'loadshed': 0.0}},
#  {'date': '2025-08-25',
#   'prediction': {'generation': 197.76869995049506,
#    'loadshed': 5.580721710801503},
#   'label': {'generation': 344.547, 'loadshed': 0.388}},
#  {'date': '2025-08-26',
#   'prediction': {'generation': 197.88219680387235,
#    'loadshed': 5.569554070303089},
#   'label': {'generation': 361.91, 'loadshed': 0.478}},
#  {'date': '2025-08-27',
#   'prediction': {'generation': 197.58027767690263,
#    'loadshed': 5.581589317515161},
#   'label': {'generation': 361.34, 'loadshed': 0.305}},
#  {'date': '2025-08-28',
#   'prediction': {'generation': 184.13364984183224,
#    'loadshed': 1.3303035419546245},
#   'label': {'generation': 353.398, 'loadshed': 0.378}}]

# %% [markdown]
# ## Write to prediction.json file

# %%
from pathlib import Path
import json

pred_file = Path("predictions.json")

if pred_file.exists():
    with open(pred_file, "r") as f:
        preds = json.load(f)
else:
    preds = {"forecast": [], "history": []}

preds["history"] = history

try:
    with open(pred_file, "w") as f:
        json.dump(preds, f, indent=2)

    print("Successfully saved predictions")
except Exception as e:
    print(f"Error occurred: {e}")
# Out:
# Successfully saved predictions
